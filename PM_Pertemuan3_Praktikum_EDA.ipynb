# %% [markdown]
# <a href="https://colab.research.google.com/github/Laila-Qodariah/pm-turi1-eda/blob/main/PM_Pertemuan3_Praktikum_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Latihan

# %%
import pandas as pd, seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df.info()         # struktur & tipe data
df.isnull().sum() # cek nilai hilang

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()        #matriks korelasi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Langkah 1 - menyiapkan pustaka dan memuat data

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
sns.set_theme (style='whitegrid')
df sns.load_dataset ('iris')    #butuh internet (Colab)
df.head()
# Out:
#   File "/tmp/ipykernel_748/4036198637.py", line 4
#     df sns.load_dataset ('iris')    #butuh internet (Colab)
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Langkah 2 - mengenali struktur

# %%
print (df.shape)               # (baris, kolom)
df.info()                      #tipe data & non-null
df.describe ()                 # statistik deskriptif
# Out:
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %% [markdown]
# Langkah 3 - memeriksa kualitas data

# %%
print(df.isnull().sum())                #nilai hilang per kolom
print (df.duplicated().sum())           #jumlah duplikat
print(df ['species'].value_counts())    # distribusi kelas
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# 1
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Langkah 4 - Distribusi (histogram & boxplot)

# %%
df.select_dtypes (include='number').hist(figsize=(9,6), bins=15)
plt.show()
sns.boxplot (data=df.select_dtypes (include='number'))
plt.title('Deteksi Outlier'); plt.show()
